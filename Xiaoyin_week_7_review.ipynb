# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoyinZeng/Hack-The-Hood-Hustle/blob/main/Xiaoyin_week_7_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conditionals

# %%
# Voting Eligibility Checker

# Step 1: Ask the user to enter their age

user_age = int(input("enter your age: "))
print(user_age)

# Step 2: Check if the age is 18 or older
if user_age >= 18:
    # If the age is 18 or older, print that the user can vote
    print("You can vote!")

# elif int(user_age) == 18:
#     print("welcome to the adult world! you can vote now!")

#reminder else
else:
    # If the age is less than 18, print that the user cannot vote yet
    print("Cannot vote yet): wait until 18.")
# Out:
# enter your age: 18
# 18
# You can vote!

# %%
# Guess the number Activity

# Edith (aka the computer) chose a 'secret' number between 1-10

secret_number = 2

# Ask the user for a number between 1 -10


secret_number = int(input("Guess a number between 1-10: "))

# The guesser (aka user) said a number that was between 1-10

# The person with the answer (aka the computer) told the user to either go higher
# or lower

if secret_number == 2:
  print("great job! you got the answer!!")

elif secret_number < 2:
  print(f"too low", "go higher", "try again")

else:
  print(f"too high", "go lower")



# the guesser (the user) guessed the correct number. IF this happens, then Edith (the computer)
# tells the guesser "Yes, that's the number!"

# %%
# Guess the number Activity

# Edith (aka the computer) chose a 'secret' number between 1-10

secret_number = 8

# Ask the user for a number between 1 -10

# The guesser (aka user) said a number that was between 1-10

number = int(input("Guess a number between 1-10"))



# The person with the answer (aka the computer) told the user to either go higher
# or lower
# the guesser (the user) guessed the correct number. IF this happens, then Edith (the computer)
# tells the guesser "Yes, that's the number!"
while number != secret_number:
  if number == secret_number:
    print("congrats, you guessed the correct number!")
  else:
    print("try again.")
  number = int(input("Guess again"))

# %% [markdown]
# # Functions

# %%
# Create a simple greeting function

def greet():
  print("Hey! how are you doing?")

# call the function

greet()
# Out:
# Hey! how are you doing?

# %%
def greet_person(name):
  print(f'Hey! {name}')

# call the function
greet_person('Xiaoyin')
# Out:
# Hey! Xiaoyin

# %%
names = ['Xiaoyin', 'AB', 'Zyishaun', 'Ayani', 'Yoline']

roster = ['Frodo','sam', 'merry ']

def greet_class(list_of_names):
  for name in list_of_names:
    print(f'Hey! {name}!!')

# call function

greet_class(names)
greet_class(roster)
# Out:
# Hey! Xiaoyin!!
# Hey! AB!!
# Hey! Zyishaun!!
# Hey! Ayani!!
# Hey! Yoline!!
# Hey! Frodo!!
# Hey! sam!!
# Hey! merry !!

# %%
secret_number = 2

secret_number = int(input("Guess a number between 1-10: "))

while number != secret_number:
  if secret_number == 2:
    print("great job! you got the answer!!")

  elif secret_number < 2:
    print(f"too low", "go higher")
  number = int(input("Guess again"))
  else:
    print(f"too high", "go lower")
  number = int(input("Guess again"))
